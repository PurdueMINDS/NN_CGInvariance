# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### Extrapolation Dataset example: MNIST-34 with G_rotation, G_verticalFlip, G_colorPermutation

# %%
# %run -i Images/datasets.py
# Out:
# Labels: tensor([3, 4])
# ...

# %% [markdown]
# ### Run CG-invariant CNN on this dataset

# %%
# %run -i Images/main.py --dataset=mnistxtra --groups=rotation_color_vflip --datasetMode='000' --model=cgcnn --numEpochs=10
# Out:
# [INFO]: Using cuda
# [INFO]: ================================================================================
# [INFO]: Configuration:
# [INFO]: {'architecture': 'vgg',
# [INFO]:  'batchSize': 64,
# [INFO]:  'cvFolds': 5,
# [INFO]:  'cvIt': 0,
# [INFO]:  'dataDir': 'data',
# [INFO]:  'dataset': 'mnistxtra',
# [INFO]:  'datasetMode': '000',
# [INFO]:  'groups': 'rotation_color_vflip',
# [INFO]:  'logLevel': 'info',
# [INFO]:  'lr': 0.001,
# [INFO]:  'model': 'cgcnn',
# [INFO]:  'momentum': 0.9,
# [INFO]:  'numEpochs': 10,
# [INFO]:  'patience': 10,
# [INFO]:  'penaltyAlpha': 10,
# [INFO]:  'penaltyMode': 'simple',
# [INFO]:  'penaltyT': 1,
# [INFO]:  'seed': 314271,
# [INFO]:  'tqdmDisable': False,
# [INFO]:  'weightDecay': 0}
# [INFO]: ================================================================================
# [INFO]: Number of classes: 2
# [INFO]: Train Dataset: mnistxtra of shape 9578
# [INFO]: Test Dataset (ood): mnistxtra of shape 1593
# ...
